# %% [markdown]
# Задание 1¶
# Придумайте функции со следующими свойствами (в a) b) c) область определения X любая, какая вам удобна, главное - функция с нужными свойствами):
#
# a) бесконечное количество локальных экстремумов
#
# b) 2 локальных экстремума
#
# с) 3 локальных экстремума
#
# d*) область определения функции - 1 точка

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.misc import derivative, electrocardiogram
from scipy.optimize import minimize, approx_fprime, fmin, brute
from scipy.signal import find_peaks

# %matplotlib inline

# %% [markdown]
# a) бесконечное количество локальных экстремумов

# %%
def f(x):
    return 1-np.sin(x)

# %%
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)

pylab.axis([-15,15,-0.3,2.3])
pylab.show()

# %% [markdown]
# b) 2 локальных экстремума

# %%
def f(x):
    return x**3-10*x

# %%
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)

pylab.axis([-15,15,-15,15])
pylab.show()

# %% [markdown]
# с) 3 локальных экстремума

# %%
def f(x):
    return 1/(x**2-1)

# %%
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)

pylab.axis([-5,1,-15,15])
pylab.show()

# %% [markdown]
# d*) область определения функции - 1 точка

# %%
def f(x):  
    return 1/0**x

#функция сущесьвует только при х==0, тк 0**0==1

# %% [markdown]
# Задание 2
# Посчитайте 1-ую и 2-ую производные функции (на бумажке):
#
# $f(x) = sin^2(2x+1)$

# %% [markdown]
# Задание 3
# Посчитайте частные производные функции в точкe (на бумажке или в LaTeX и на numpy):
#
# $f(x,y)=2x^2y^3 + 1/x + y^2x + 7$ в точке $(1,2)$

# %%
def func(x):
    "Coordinate vector `x` should be an array of size two."
    return 2*(x[0]**2)*(x[1]**3)+1/x[0]+(x[1]**2)*x[0]

# %%
#x = np.ones(2)
x = np.array([1.,2.])
eps = np.sqrt(np.finfo(float).eps)
approx_fprime(x, func, [eps, eps])
# Out:
# array([35.00000024, 28.00000024])

# %% [markdown]
# Задание 4: Градиентный спуск своими руками

# %%
def f(x):
    return (x[0]**2) + (x[1]**2)

# %%
x = np.array([100, 200])
lr = 0.1

# %%
eps = np.sqrt(np.finfo(float).eps)
for i in range(100):
    # Calculate gradient
    grad = approx_fprime(x, f, [eps, eps])# Your code here (функция для вычисления градиента есть в лекционном ноутбуке)
    x = x - grad*lr

# %%
print("Минимум достигается в: ", x)
print("Значение функции в минимуме: ", f(x))
# Out:
# Минимум достигается в:  [-7.45058069e-09 -7.45058069e-09]
# Значение функции в минимуме:  1.1102230526720674e-16

# %%
res = minimize(f, x, method='nelder-mead', options={'xtol': 1e-6, 'disp': True})
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1
#          Function evaluations: 3
